# %% [markdown]
# # Progetto del corso - Introduzione alla Data Science e al pensiero computazionale - a.a. 2025/2026

# %% [markdown]
# # Membri del gruppo numero 12

# %% [markdown]
# Il gruppo numero 12 è composto da:
#
# *   **Nicoletta Aloisi:** matricola 1216124, email nicoletta.aloisi@studio.unibo.it
# *   **Erika Avdiaj:** matricola 1226030, email erika.avdiaj@studio.unibo.it
# *   **Giannalisa Romeo:** matricola 1216078, email giannalisa.romeo@studio.unibo.it

# %% [markdown]
# # Materiale del progetto
#
# Il materiale del progetto è disponibile sul sito del corso e contiene i seguenti dataset:
#
# * *Bank_Marketing*
# * *Credit_Card_Default*
# * *Customer_Churn*
# * *Employee_Attrition*
# * *Online_Shoppers*

# %% [markdown]
# # Preparazione dell'ambiente

# %% [markdown]
# Prima di iniziare questa parte dobbiamo preparare l'ambiente Colab importando **Pandas**, **Seaborn** e **Scikit-learn**, le librerie Python che abbiamo visto in questo corso.
#
# ```python
# # Pandas
# import pandas as pd
# import numpy as np
#
# # Seaborn
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Scikit-learn
# from sklearn import svm, tree
# from sklearn.metrics import *
#
# # riportare nella cella di codice seguente ed eseguire:
# # da questo punto in poi le estensioni Pandas, Seaborn e Scikit-learn
# # sone attive e possiamo usarle per tutto il resto del notebook.
# ```

# %%
# Pandas
import pandas as pd
import numpy as np

# Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# Scikit-learn
from sklearn import svm, tree
from sklearn.metrics import *

# riportare nella cella di codice seguente ed eseguire:
# da questo punto in poi le estensioni Pandas, Seaborn e Scikit-learn
# sone attive e possiamo usarle per tutto il resto del notebook.

# %%
train = pd.read_csv("sample_data/Employee_Attrition.csv", sep=",")

# %%
train.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Fase 1

# %% [markdown]
# Svolgere in questa sezione e nelle tre seguenti le fasi del progetto.
#
# Caricare training dataset e test dataset e iniziare le analisi.

# %% [markdown]
# Aggiungere celle di testo e codice, e usare intestazioni (sezioni, sottosezioni, ecc.) per organizzare i contenuti. Ad esempio:

# %% [markdown]
# ## Domanda 1.1
#
# Bla bla bla.

# %% [markdown]
# ## Domanda 1.2
#
# Bla bla bla.

# %% [markdown]
# Ecc.

# %% [markdown]
# # Fase 2

# %% [markdown]
# # Fase 3

# %% [markdown]
# # Conslusioni
